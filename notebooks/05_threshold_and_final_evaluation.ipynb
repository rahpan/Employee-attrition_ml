# %% [markdown]
# # Stage 5 — Threshold policy and final evaluation
#
# **Product Owner decision:** Prioritize fewer false alerts, subject to a minimum 40% validation recall guardrail.

# %%
import sys
from pathlib import Path
project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(project_root))
from src.stage5_threshold_final_evaluation import run_stage5
results = run_stage5()

# %%
results['threshold_policy']['selected_threshold']

# %%
results['test_metrics']

# %% [markdown]
# ## Product Owner interpretation
#
# A higher probability threshold requires stronger model evidence before producing an alert. This reduces false alerts but generally increases missed attrition. The threshold must therefore be connected to the approved business action and reviewed after deployment.

# %%
results['coefficient_associations']

# %% [markdown]
# ## Explainability caution
#
# Positive coefficients are associated with higher predicted attrition and negative coefficients with lower predicted attrition. They do not prove that changing a feature will cause attrition to change.
