# %% [markdown]
# # Stage 4 — Train candidate models
#
# **Product Owner question:** Which candidate provides useful attrition detection while remaining explainable and governable?

# %%
import sys
from pathlib import Path
project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(project_root))
from src.stage4_train_models import train_and_compare
models, results = train_and_compare()

# %%
results['candidate_metrics']

# %% [markdown]
# ## Reading the confusion matrix
#
# `true_positive` means actual attrition correctly identified. `false_negative` means attrition missed. `false_positive` means a staying employee was flagged. `true_negative` means a staying employee was correctly classified.

# %%
{
    'selection_metric': results['selection_metric'],
    'recommended_candidate': results['recommended_candidate'],
    'test_set_status': results['test_set_status'],
}

# %% [markdown]
# ## Product Owner interpretation
#
# A recommendation based on validation data is not a production approval. We still need to choose an operating threshold, evaluate the untouched test set once, examine explainability and subgroup performance, and complete governance review.
