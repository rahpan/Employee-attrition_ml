# %% [markdown]
# # Stage 6 — Package, score, and monitor
#
# **Product Owner question:** Can the selected model operate as a governed aggregate workforce-planning product?

# %%
import sys
from pathlib import Path
project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(project_root))
from src.stage1_data_profile import load_data
from src.stage6_package_and_monitor import (
    train_and_package_model, score_aggregate_workforce, monitoring_snapshot
)
model, metadata = train_and_package_model()
df = load_data()

# %%
score_aggregate_workforce(model, df)

# %% [markdown]
# ## Privacy-by-design output
#
# The scoring function calculates probabilities internally but returns only department-level summaries. It does not return EmployeeNumber or individual risk scores. Groups below the minimum reporting size are suppressed.

# %%
monitoring_snapshot(model, df)

# %% [markdown]
# ## Production interpretation
#
# Packaging a model is not the same as approving it for production. Production requires point-in-time data, governance approval, security controls, UAT, operational monitoring, support ownership, and a rollback plan.
